# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import rc
from matplotlib.ticker import FuncFormatter

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook
#%matplotlib inline

# %% [markdown]
# # I Please fill the next list with desired chains to annalize

# %%
# Fill the next list with desired chains to annalize -------------------

chain_root_baojla_nierika=[
            #'../chains/N1_nierika/bao_jla/nrk_11-28_cluster1_f1.5/nrk_11-28_cluster1_f1.5'
            '../chains/N1_nierika/bao_jla/nrk_11-28_cluster2_f1.7_CONVERGED/nrk_11-28_cluster2_f1.7_CONVERGED'
            ,'../chains/N1_nierika/bao_jla/nrk_12-1_cluster2_f1.7_CONVERGED/nrk_12-1_cluster2_f1.7_CONVERGED'
            #,'../chains/lcdm/lcdm_12-3_local2/lcdm_12-3_local2'
]

chain_root_baojla_nakawe=[
            '../chains/N2_nakawe/bao_jla/nkw_11-28_cluster1_f1.5/nkw_11-28_cluster1_f1.5'
            ,'../chains/N2_nakawe/bao_jla/nkw_11-28_cluster2_f1.7/nkw_11-28_cluster2_f1.7'
            ,'../chains/N2_nakawe/bao_jla/nkw_11-26_cluster_f1.5/nkw_11-26_cluster_f1.5'
            ,'../chains/N2_nakawe/bao_jla/nkw_12-10_cluster1_f1.7/nkw_12-10_cluster1_f1.7'
]

chain_root_planck_nierika=['../chains/N1_nierika/planck_bao_jla/nrk_12-1_cluster1_f1.7/nrk_12-1_cluster1_f1.7'
]

chain_root_planck_nakawe=['../chains/N2_nakawe/bao_jla_planck/nkw_1-3_cluster1_f1.7/nkw_1-3_cluster1_f1.7'
]

# %% [markdown]
# # --------------------------------------------------------------------------------------

# %% [markdown]
# # II Reading and arranging data section:

# %% [markdown]
# ### w(N=1)

# %%
# Nierika BAO + JLA

how_many_chains1=len(chain_root_baojla_nierika)

R1=[]


for i in chain_root_baojla_nierika:
    
    #these lines read .h_info (for R-1 values) and .v_info (for names of parameters) 
    r1=np.genfromtxt(i+'.h_info', skip_header=1, delimiter=':',dtype=None)
    nam1=np.genfromtxt(i+'.v_info', skip_header=1, delimiter=':',dtype=None)
    
    #these lines convert the string 'r1'...
    v1=r1[0,1].tostring()                       #array with just R-1numbers.(numbers as strings)
    f1=v1.split('\t')                            #float list with R-1 numbers as floats
    f1.pop()                                    #removes last element of list (because it appears "empty")
    
    #these line converts 'nam' into a list of names
    names1=nam1[:,0]
    
    #print f
    #print names
    
    R1.append(f1)

#print(R1)

for i in range(len(R1)):
    print 'R-1 values for N=1 with BAO + JLA chain', i, 'are:'
    print R1[i]
# Out:
# R-1 values for N=1 with BAO + JLA chain 0 are:
# ['  0.053336', ' 0.049063', ' 0.021824', ' 0.031428', ' 0.045918', ' 0.003614']
# R-1 values for N=1 with BAO + JLA chain 1 are:
# ['  0.050494', ' 0.076455', ' 0.016913', ' 0.043105', ' 0.080470', ' 0.001020']

# %%
# Nierika BAO + JLA + PLANCK

how_many_chains2=len(chain_root_planck_nierika)
#for i in chain_root:
#    print i

R2=[]


for j in chain_root_planck_nierika:
    
    #these lines read .h_info (for R-1 values) and .v_info (for names of parameters) 
    r2=np.genfromtxt(j+'.h_info', skip_header=1, delimiter=':',dtype=None)
    nam2=np.genfromtxt(j+'.v_info', skip_header=1, delimiter=':',dtype=None)
    
    #these lines convert the string 'r1'...
    v2=r2[0,1].tostring()                       #array with just R-1numbers.(numbers as strings)
    f2=v2.split('\t')                            #float list with R-1 numbers as floats
    f2.pop()                                    #removes last element of list (because it appears "empty")
    
    #these line converts 'nam' into a list of names
    names2=nam2[:,0]    
    R2.append(f2)


for j in range(len(R2)):
    print 'R-1 values for N=1 chain with Planck + BAO + JLA', j, 'are:'
    print R2[j]
# Out:
# R-1 values for N=1 chain with Planck + BAO + JLA 0 are:
# ['  0.011993', ' 0.034356', ' 0.006947', ' 0.024151', ' 0.009334', ' 0.163448', ' 0.173961', ' 0.086971', ' 0.008312', ' 0.059454', ' 0.007358']

# %% [markdown]
# # --------------------------------------------------------------------------------------

# %% [markdown]
# ### w(N=2)

# %%
# Nakawe BAO + JLA

how_many_chains12=len(chain_root_baojla_nakawe)

R12=[]


for i in chain_root_baojla_nakawe:
    
    #these lines read .h_info (for R-1 values) and .v_info (for names of parameters) 
    r12=np.genfromtxt(i+'.h_info', skip_header=1, delimiter=':',dtype=None)
    nam12=np.genfromtxt(i+'.v_info', skip_header=1, delimiter=':',dtype=None)
    
    #these lines convert the string 'r1'...
    v12=r12[0,1].tostring()                       #array with just R-1numbers.(numbers as strings)
    f12=v12.split('\t')                            #float list with R-1 numbers as floats
    f12.pop()                                    #removes last element of list (because it appears "empty")
    
    #these line converts 'nam' into a list of names
    names12=nam12[:,0]
    
    #print f
    #print names
    
    R12.append(f12)


for i in range(len(R12)):
    print 'R-1 values for N=2 with BAO + JLA data chain', i, 'are:'
    print R12[i]
# Out:
# R-1 values for N=2 with BAO + JLA data chain 0 are:
# ['  0.347998', ' 0.266649', ' 0.247520', ' 0.608530', ' 0.533272', ' 0.252058', ' 0.068578']
# R-1 values for N=2 with BAO + JLA data chain 1 are:
# ['  0.810696', ' 0.734049', ' 0.076105', ' 0.449300', ' 0.154895', ' 0.716064', ' 0.050741']
# R-1 values for N=2 with BAO + JLA data chain 2 are:
# ['  1.066846', ' 0.999714', ' 0.307370', ' 0.462133', ' 0.780197', ' 0.929409', ' 0.043147']
# R-1 values for N=2 with BAO + JLA data chain 3 are:
# ['  0.062876', ' 0.066430', ' 0.034118', ' 0.102101', ' 0.037434', ' 0.069907', ' 0.012862']

# %%
# Nakawe BAO + JLA + PLANCK

how_many_chains2=len(chain_root_planck_nierika)
#for i in chain_root:
#    print i

R22=[]


for j in chain_root_planck_nakawe:
    
    #these lines read .h_info (for R-1 values) and .v_info (for names of parameters) 
    r22=np.genfromtxt(j+'.h_info', skip_header=1, delimiter=':',dtype=None)
    nam22=np.genfromtxt(j+'.v_info', skip_header=1, delimiter=':',dtype=None)
    
    #these lines convert the string 'r1'...
    v22=r22[0,1].tostring()                       #array with just R-1numbers.(numbers as strings)
    f22=v22.split('\t')                            #float list with R-1 numbers as floats
    f22.pop()                                    #removes last element of list (because it appears "empty")
    
    #these line converts 'nam' into a list of names
    names22=nam22[:,0]    
    R22.append(f22)


for j in range(len(R22)):
    print 'R-1 values for N=2 chain with Planck + BAO + JLA', j, 'are:'
    print R22[j]
# Out:
# R-1 values for N=2 chain with Planck + BAO + JLA 0 are:
# ['  0.012802', ' 0.027709', ' 0.003173', ' 0.018789', ' 0.004389', ' 0.679331', ' 2.965032', ' 4.024087', ' 0.070715', ' 0.003999', ' 0.074621', ' 0.049854']

# %% [markdown]
# # --------------------------------------------------------------------------------------

# %% [markdown]
# # III Plotting section

# %% [markdown]
# ### w(N=1)

# %%
# Nierika BAO + JLA

ind1 = np.arange(len(R1[0]))           # the x locations for the groups, where len(test) is the no. of parameters
width1 = 0.9/(len(chain_root_baojla_nierika))         # the width of the bars

fig, ax = plt.subplots(figsize=(9,7))

plot_ch1 = ax.bar(ind1, R1[0], width1,label=chain_root_baojla_nierika[0])
plot_ch2 = ax.bar(ind1 + width1, R1[1], width1,label=chain_root_baojla_nierika[1])



#ax.bar(x,test)
#ax.bar(x,test2)

#ax.plot(names,test,'o')
#ax.plot(names,test2,'o')


#--------------------------------------------------------------------------------------
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.set_xlabel(r'Parameters',fontsize=15)
ax.set_ylabel(r'R-1 convergence criterium',fontsize=15)
#ax.set_ylim(0,0.5)
ax.grid(which='both',ls=":", c='black',alpha=0.4)
ax.set_title(r'N=1 with BAO + JLA convergence test')
ax.axhline(y=0.01, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.axhline(y=0.05, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.set_xticks(ind1 + width1 / len(R1))
ax.set_xticklabels((r'$\omega_b$', r'$\omega_{cdm}$', r'$b_0$', r'$b_1$',
                    r'$\Omega_{\Lambda}$',r'$H_0$'))


plt.savefig("convergence_baojla_N=1.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
ind2 = np.arange(len(R2[0]))           # the x locations for the groups, where len(test) is the no. of parameters
width2 = 0.9/(len(chain_root_planck_nierika))         # the width of the bars

fig, ax = plt.subplots(figsize=(9,7))

plot_pl1= ax.bar(ind2, R2[0], width2,label=chain_root_planck_nierika[0])



#--------------------------------------------------------------------------------------
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.set_xlabel(r'Parameters',fontsize=15)
ax.set_ylabel(r'R-1 convergence criterium',fontsize=15)
#ax.set_ylim(0,0.5)
ax.grid(which='both',ls=":", c='black',alpha=0.4)
ax.set_title(r'N=1 with Planck + BAO + JLA convergence test')
ax.axhline(y=0.01, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.axhline(y=0.05, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.set_xticks(ind2 #+ width2/len(R2)
             )
ax.set_xticklabels((r'$\omega_b$', r'$\omega_{cdm}$',r'$10^{-9}A_{s }$', r'$n_{s}$', r'$\tau_{reio }$',
                    r'$b_0$', r'$b_1$', r'$\Omega_{\Lambda}$',r'$z_{reio }$',r'$H_0$',r'$\sigma8$'))

plt.savefig("convergence_planckbaojla_N=1.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # --------------------------------------------------------------------------------------------------

# %% [markdown]
# ### w(N=2)

# %%
# Nakawe BAO + JLA

ind12 = np.arange(len(R12[0]))           # the x locations for the groups, where len(test) is the no. of parameters
width12 = 0.9/(len(chain_root_baojla_nakawe))         # the width of the bars

fig, ax = plt.subplots(figsize=(9,7))

plot_ch1 = ax.bar(ind12, R12[0], width12,label=chain_root_baojla_nakawe[0])
plot_ch2 = ax.bar(ind12 + width12, R12[1], width12,label=chain_root_baojla_nakawe[1])
plot_ch3 = ax.bar(ind12 + 2*width12, R12[2], width12,label=chain_root_baojla_nakawe[2])
plot_ch4 = ax.bar(ind12 + 3*width12, R12[3], width12,label=chain_root_baojla_nakawe[3])

#--------------------------------------------------------------------------------------
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.set_xlabel(r'Parameters',fontsize=15)
ax.set_ylabel(r'R-1 convergence criterium',fontsize=15)
#ax.set_ylim(0,0.5)
ax.grid(which='both',ls=":", c='black',alpha=0.4)
ax.set_title(r'N=2 with BAO + JLA convergence test')
ax.axhline(y=0.01, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.axhline(y=0.05, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.set_xticks(ind12 + width12 / len(R12))
ax.set_xticklabels((r'$\omega_b$', r'$\omega_{cdm}$', r'$b_0$', r'$b_1$', r'$b_2$',
                    r'$\Omega_{\Lambda}$',r'$H_0$'))


plt.savefig("convergence_baojla_N=2.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Nakawe BAO + JLA + Planck

ind22 = np.arange(len(R22[0]))           # the x locations for the groups, where len(test) is the no. of parameters
width22 = 0.9/(len(chain_root_planck_nakawe))         # the width of the bars

fig, ax = plt.subplots(figsize=(9,7))

plot_pl1= ax.bar(ind22, R22[0], width22,label=chain_root_planck_nakawe[0])



#--------------------------------------------------------------------------------------
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.set_xlabel(r'Parameters',fontsize=15)
ax.set_ylabel(r'R-1 convergence criterium',fontsize=15)
#ax.set_ylim(0,0.5)
ax.grid(which='both',ls=":", c='black',alpha=0.4)
ax.set_title(r'N=2 with Planck + BAO + JLA convergence test')
ax.axhline(y=0.01, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.axhline(y=0.05, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.set_xticks(ind22 #+ width2/len(R2)
             )
ax.set_xticklabels((r'$\omega_b$', r'$\omega_{cdm}$',r'$10^{-9}A_{s }$', r'$n_{s}$', r'$\tau_{reio }$',
                    r'$b_0$', r'$b_1$', r'$b_2$', r'$\Omega_{\Lambda}$',r'$z_{reio }$',r'$H_0$',r'$\sigma8$'))

plt.savefig("convergence_planckbaojla_N=2.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">
