# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook

# %%
#test 1

chain1=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__1.txt')
chain2=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__2.txt')
chain3=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__3.txt')
chain4=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__4.txt')
chain5=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__5.txt')
chain6=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__6.txt')
chain7=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__7.txt')
chain8=np.loadtxt('./../chains/nearika_bothfree_sept14/2018-09-14_120001__8.txt')

# %%
#first run with 240,000 steps

chain1=np.loadtxt('./../chains/nearika_jlabao_oct12/2018-10-12_240002__1.txt')
chain2=np.loadtxt('./../chains/nearika_jlabao_oct12/2018-10-12_240002__2.txt')
chain3=np.loadtxt('./../chains/nearika_jlabao_oct12/2018-10-12_240002__3.txt')
chain4=np.loadtxt('./../chains/nearika_jlabao_oct12/2018-10-12_240002__4.txt')
chain5=np.loadtxt('./../chains/nearika_jlabao_oct12/2018-10-12_240002__5.txt')
chain6=np.loadtxt('./../chains/nearika_jlabao_oct12/2018-10-12_240002__6.txt')

# %%
chain1.shape
# Out:
# (50161, 13)

# %%
print(chain1[:,0])
# Out:
# [   1.    4.    3. ...,   40.  148.    7.]

# %%
l1=np.arange(len(chain1))
l2=np.arange(len(chain2))
l3=np.arange(len(chain3))
l4=np.arange(len(chain4))
l5=np.arange(len(chain5))
l6=np.arange(len(chain6))
#l7=np.arange(len(chain7))
#l8=np.arange(len(chain8))

# %%
print l1
print l2
# Out:
# [    0     1     2 ..., 50158 50159 50160]
# [    0     1     2 ..., 13910 13911 13912]

# %%
print l1
# Out:
# [    0     1     2 ..., 50158 50159 50160]

# %%
fig, ax = plt.subplots(figsize=(9,7))

# Param 1
ax.plot(l1,chain1[:,2],label=r'$T_{CMB}$',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,3],label=r'$h$',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,4],label=r'$10^{2} \omega_{b}$',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,5],'b',label=r'$\Omega_{cdm}$',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,6],label=r'10^{9} A_{s }',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,7],label=r'n_s',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,8],label=r'\tau_{reio }',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,9],label=r'b0_{fld } ',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,10],label=r'b1_{fld } ',alpha=1,linewidth=1)
ax.plot(l1,chain1[:,11],label=r'\Omega_{fld}',alpha=1,linewidth=1)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'steps',fontsize=15)
ax.set_ylabel(r'parameter value',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'Ten-parameter exploration MCMC, JLA+BAO, chain 1');
plt.savefig("plot1_1_jlabao_oct12_240k.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

# Param 1
ax.plot(l2,chain2[:,2],label=r'$T_{CMB}$',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,3],label=r'$h$',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,4],label=r'$10^{2} \omega_{b }$',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,5],'b',label=r'$\Omega_{cdm}$',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,6],label=r'10^{9} A_{s }',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,7],label=r'n_s',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,8],label=r'\tau_{reio }',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,9],label=r'b0_{fld } ',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,10],label=r'b1_{fld } ',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,11],label=r'\Omega_{fld}',alpha=1,linewidth=1)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'steps',fontsize=15)
ax.set_ylabel(r'parameter value',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'Ten-parameter exploration MCMC, JLA+BAO, chain 2');
plt.savefig("plot1_2_jlabao_oct12_240k.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

ax.plot(l3,chain3[:,2],label=r'$T_{CMB}$',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,3],label=r'$h$',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,4],label=r'$10^{2} \omega_{b }$',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,5],'b',label=r'$\Omega_{cdm}$',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,6],label=r'10^{9} A_{s }',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,7],label=r'n_s',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,8],label=r'\tau_{reio }',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,9],label=r'b0_{fld } ',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,10],label=r'b1_{fld } ',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,11],label=r'\Omega_{fld}',alpha=1,linewidth=1)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'steps',fontsize=15)
ax.set_ylabel(r'parameter value',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'Ten-parameter exploration MCMC, JLA+BAO, chain 3');
plt.savefig("plot1_3_jlabao_oct12_240k.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

ax.plot(l1,chain1[:,6],'b',label=r'chain 1',alpha=1,linewidth=1)
ax.plot(l2,chain2[:,6],'b',label=r'chain 2',alpha=1,linewidth=1)
ax.plot(l3,chain3[:,6],'b',label=r'chain 3',alpha=1,linewidth=1)
ax.plot(l4,chain4[:,6],'b',label=r'chain 4',alpha=1,linewidth=1)
ax.plot(l5,chain5[:,6],'b',label=r'chain 5',alpha=1,linewidth=1)
ax.plot(l6,chain6[:,6],'b',label=r'chain 6',alpha=1,linewidth=1)
#ax.plot(l7,chain7[:,6],'b',label=r'chain 7',alpha=1,linewidth=1)
#ax.plot(l8,chain8[:,6],'b',label=r'chain 8',alpha=1,linewidth=1)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'steps',fontsize=15)
ax.set_ylabel(r'10^{-9}A_{s }',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'wellness of exploration for 1 parameter using all 6 (240k-step) chains');
plt.savefig("plot2_1_jlabao_oct12_240k.pdf")

# %%
fig, ax = plt.subplots(figsize=(9,7))

ax.plot(l1,chain1[:,6],'b',label=r'chain 1',alpha=1,linewidth=1)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'steps',fontsize=15)
ax.set_ylabel(r'10^{-9}A_{s }',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'wellness of exploration for 1 parameter using ONE chain');
plt.savefig("plot3_1_jlabao_oct12_240k.pdf")

# %%
print chain1

# %%
print chain1[0,:]

# %%
print chain1[:,0]

# %%
promedios=[]

for i in range(len(chain1)):           #para cada fila del array chain1....
    #print i
    fila_i=chain1[i,:]                 #aquí ya escogimos la fila
    
    j=2
    suma=0
    while j<13:                        #ahora le decimos que empiece a barrer todos los elementos de la fila
        suma = suma + fila_i[j]        #cuya posición esté entre el valor 2(segundo) y el 17(último)
        #print suma
        j=j+1
        if j==13:
            break

    promedio = suma/15
    print promedio
    promedios.append(promedio)
    
print promedios

# %%
lprom=np.arange(len(promedios))
print lprom

# %%
fig, ax = plt.subplots(figsize=(9,7))

ax.plot(lprom,promedios,'b',alpha=1,linewidth=1)


#--------------------------------------------------------------------------------------
#ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'steps',fontsize=15)
ax.set_ylabel(r'media muestral',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'media muestral de la cadena 1');
